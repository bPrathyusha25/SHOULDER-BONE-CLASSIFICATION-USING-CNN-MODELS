# %% [markdown]
# #  **Import the required Library and Packages**

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import os
import cv2
import pickle
from skimage.transform import rescale, resize
from sklearn.utils import class_weight
from skimage.io import imread
from sklearn.utils import shuffle
from matplotlib import pyplot as plt
from sklearn.metrics import  classification_report,confusion_matrix
from sklearn import metrics
from sklearn.metrics import plot_roc_curve

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Preprocessing**

# %% [markdown]
# > # **File Handling**

# %%
def get_filename(part,train=True):
    root='../input/mura-v11/'
    if train:
        csv_path="../input/mura-v11/MURA-v1.1/train_image_paths.csv"
    else:
        csv_path="../input/mura-v11/MURA-v1.1/valid_image_paths.csv"
    
    with open(csv_path, 'rb') as F:
        d = F.readlines()
        if part == 'all':
            imgs = [root + str(x, encoding='utf-8').strip() for x in d]  
        else:
            imgs = [root + str(x, encoding='utf-8').strip() for x in d if
                            str(x, encoding='utf-8').strip().split('/')[2] == part]

    #imgs= [x.replace("/", "\\") for x in imgs]
    labels= [x.split('_')[-1].split('/')[0] for x in imgs]
    return imgs,labels


#To icrop a image from center
def crop_center(img,cropx,cropy):
    y,x,_ = img.shape
    startx = x//2-(cropx//2)
    starty = y//2-(cropy//2)    
    return img[starty:starty+cropy,startx:startx+cropx]

# %% [markdown]
# > # **Data Augmentation**

# %%
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,
    ToFloat, ShiftScaleRotate
)
from albumentations.augmentations.transforms import Resize
AUGMENTATIONS_TRAIN = Compose([
    HorizontalFlip(p=0.5),
    RandomContrast(limit=0.2, p=0.5),
    RandomGamma(gamma_limit=(80, 120), p=0.5),
    RandomBrightness(limit=0.2, p=0.5),
    ShiftScaleRotate(
        shift_limit=0.0625, scale_limit=0.1, 
        rotate_limit=15, border_mode=cv2.BORDER_REFLECT_101, p=0.8), 
    ToFloat(max_value=255)
])
AUGMENTATIONS_TEST = Compose([
    ToFloat(max_value=255)
])

# %%
albumentation_list =  [
    HorizontalFlip(p=0.5),
    RandomContrast(limit=0.2, p=0.5),
    RandomGamma(gamma_limit=(80, 120), p=0.5),
    RandomBrightness(limit=0.2, p=0.5),
    ShiftScaleRotate(
        shift_limit=0.0625, scale_limit=0.1, 
        rotate_limit=15, border_mode=cv2.BORDER_REFLECT_101, p=0.8), 
    ToFloat(max_value=255)
]
root='../input/mura-v11/'
chosen_image= imread(root+'MURA-v1.1/train/XR_SHOULDER/patient01055/study1_positive/image3.png')
img_matrix_list = []
bboxes_list = []
for aug_type in albumentation_list:
    img = aug_type(image = chosen_image)['image']
    img_matrix_list.append(img)
img_matrix_list = img_matrix_list[:-1]  
img= resize(chosen_image,(300,300,3))
img_matrix_list.append(img)
img_matrix_list.append(crop_center(img,224,224))

img_matrix_list.insert(0,chosen_image)    

titles_list = ["Original","Horizontal Flip","Random Contrast","Random Gamma","RandomBrightness",
               "Shift Scale Rotate","Resizing", "Cropping"]

def plot_img(img_matrix_list, title_list, ncols, main_title="Augmentation"):
    fig, myaxes = plt.subplots(figsize=(20, 15), nrows=2, ncols=ncols, squeeze=True)
    fig.suptitle(main_title, fontsize = 30)
    for i, (img, title) in enumerate(zip(img_matrix_list, title_list)):
        myaxes[i // ncols][i % ncols].imshow(img)
        myaxes[i // ncols][i % ncols].set_title(title, fontsize=15)
    plt.show()
    
plot_img(img_matrix_list, titles_list, ncols = 4)

# %% [markdown]
# > # **Data Generator**

# %%
class Data_Generator(keras.utils.Sequence) :
  
  def __init__(self, image_filenames, labels, batch_size,transform) :
    self.image_filenames = image_filenames
    self.labels = labels
    self.batch_size = batch_size
    self.t= transform
    
  def __len__(self) :
    return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
    batch_y = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]
    x=[]
    for file in batch_x:
        img= imread(file)
        img= self.t(image=img)["image"]
        img= resize(img,(300,300,3))
        img= crop_center(img,224,224)
        x.append(img)
    x=np.array(x)/255.0
    y= np.array(batch_y)
    return x,y

# %%
part='XR_SHOULDER'
imgs,labels= get_filename(part=part)
val_imgs,val_labels= get_filename(part=part,train=False)
print(labels.count('positive'),labels.count('negative'))
training_data= labels.count('positive')+labels.count('negative')
print("Training Data: ", training_data)
train_y_data= [0 if x=='positive' else 1 for x in labels]
train_y_data= keras.utils.to_categorical(train_y_data)
print(val_labels.count('positive'),val_labels.count('negative'))
validation_data= val_labels.count('positive')+val_labels.count('negative')
print("Validation Data: ", validation_data)
val_y_data= [0 if x=='positive' else 1 for x in val_labels]
val_y_data= keras.utils.to_categorical(val_y_data)
# Out:
# 4168 4211
# Training Data:  8379
# 278 285
# Validation Data:  563

# %%
from sklearn.utils.class_weight import compute_class_weight

y_int = np.argmax(train_y_data, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_int), y_int)
d_class_weights = dict(enumerate(class_weights))

# %% [markdown]
# **Training and Validation Data Generators**

# %%
batch_size = 32
imgs, train_y_data = shuffle(imgs, train_y_data)
training_batch_gen = Data_Generator(imgs, train_y_data, batch_size,AUGMENTATIONS_TRAIN)
validation_batch_gen = Data_Generator(val_imgs, val_y_data, batch_size,AUGMENTATIONS_TEST)

# %% [markdown]
# > # **Model Building**

# %% [markdown]
# > # **Resnet34**

# %%
! pip install git+https://github.com/qubvel/classification_models.git
from classification_models.keras import Classifiers
# Out:
# Collecting git+https://github.com/qubvel/classification_models.git
#   Cloning https://github.com/qubvel/classification_models.git to /tmp/pip-req-build-lir5fn5m
#   Running command git clone -q https://github.com/qubvel/classification_models.git /tmp/pip-req-build-lir5fn5m
#   Running command git submodule update --init --recursive -q
# Collecting keras_applications<=1.0.8,>=1.0.7
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 272 kB/s eta 0:00:01
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.19.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.15.0)
# Building wheels for collected packages: image-classifiers
#   Building wheel for image-classifiers (setup.py) ... done
#   Created wheel for image-classifiers: filename=image_classifiers-1.0.0-py3-none-any.whl size=20030 sha256=0e31b827a9eeb1353bd11f42258d97c86fd8d06cf30b245a8c1bdeb0c6e343d1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qh17wyjz/wheels/0b/96/56/27b17c903efc647c51e4f364bfc20aa67f8d3dccad63c4fb4e
# Successfully built image-classifiers
# Installing collected packages: keras-applications, image-classifiers
# Successfully installed image-classifiers-1.0.0 keras-applications-1.0.8

# %%
ResNet34, _ = Classifiers.get('resnet34')


resnet34 = ResNet34(input_shape=(224,224,3), weights='imagenet', include_top=False)
input_image=keras.layers.Input((224,224,3))
x= resnet34(input_image)

x=keras.layers.Flatten()(x)
x=keras.layers.Dense(256)(x)
x=keras.layers.Activation(activation='relu')(x)
x= keras.layers.Dropout(0.5)(x)
x=keras.layers.Dense(2)(x)
out=keras.layers.Activation(activation='softmax')(x)

model=keras.Model(inputs=input_image,outputs=out)
model.compile(optimizer=keras.optimizers.RMSprop(lr=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])
print(model.summary())
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000_no_top.h5
# 85524480/85521592 [==============================] - 4s 0us/step
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# model (Functional)           (None, 7, 7, 512)         21302473
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               6422784
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 27,725,771
# Trainable params: 27,710,405
# Non-trainable params: 15,366
# _________________________________________________________________
# None

# %%
history=model.fit_generator(generator=training_batch_gen,
                   steps_per_epoch = int(training_data // batch_size),
                   epochs = 5,
                   verbose = 1,
                   class_weight=d_class_weights,
                   validation_data = validation_batch_gen,
                   validation_steps = int(validation_data // batch_size),
                           )
# Out:
# Epoch 1/5
# 261/261 [==============================] - 564s 2s/step - loss: 1.2869 - accuracy: 0.6029 - val_loss: 0.7286 - val_accuracy: 0.4890
# Epoch 2/5
# 261/261 [==============================] - 429s 2s/step - loss: 0.5864 - accuracy: 0.7255 - val_loss: 0.7053 - val_accuracy: 0.4890
# Epoch 3/5
# 261/261 [==============================] - 424s 2s/step - loss: 0.5346 - accuracy: 0.7587 - val_loss: 0.6967 - val_accuracy: 0.4890
# Epoch 4/5
# 261/261 [==============================] - 428s 2s/step - loss: 0.5419 - accuracy: 0.7591 - val_loss: 0.7168 - val_accuracy: 0.4871
# Epoch 5/5
# 261/261 [==============================] - 427s 2s/step - loss: 0.5133 - accuracy: 0.7690 - val_loss: 0.7454 - val_accuracy: 0.5165

# %%
y_pred=  model.predict(validation_batch_gen)
y_pred = np.argmax(y_pred,axis = 1)
y_act = np.argmax(val_y_data,axis = 1)

# %%
print(classification_report(y_act,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.07      0.13       278
#            1       0.52      0.98      0.68       285
#
#     accuracy                           0.53       563
#    macro avg       0.66      0.53      0.41       563
# weighted avg       0.66      0.53      0.41       563

# %%
metrics.cohen_kappa_score(y_act,y_pred)
# Out:
# 0.055013434255116844

# %%
confusion_matrix(y_act,y_pred)
# Out:
# array([[ 20, 258],
#        [  5, 280]])

# %%
fpr, tpr, thresh = metrics.roc_curve(y_act,y_pred)
auc = metrics.roc_auc_score(y_act,y_pred)
plt.plot(fpr,tpr,label="ResNet34, auc="+str(auc))
plt.legend()

# %% [markdown]
# > # **MobilNet**

# %%
Mn=keras.applications.MobileNet(include_top=False,input_shape=(224,224,3))
input_image=keras.layers.Input((224,224,3))
x=Mn (input_image)

x=keras.layers.Flatten()(x)
x=keras.layers.Dense(256)(x)
x=keras.layers.Activation(activation='relu')(x)
x= keras.layers.Dropout(0.5)(x)
x=keras.layers.Dense(2)(x)
out=keras.layers.Activation(activation='softmax')(x)

model_mn=keras.Model(inputs=input_image,outputs=out)
model_mn.compile(optimizer=keras.optimizers.RMSprop(lr=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               25690368
# _________________________________________________________________
# activation_6 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 514
# _________________________________________________________________
# activation_7 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 49,278,594
# Trainable params: 49,225,474
# Non-trainable params: 53,120
# _________________________________________________________________
# None

# %%
history=model_mn.fit_generator(generator=training_batch_gen,
                   steps_per_epoch = int(training_data // batch_size),
                   epochs = 5,
                   verbose = 1,
                   class_weight=d_class_weights,
                   validation_data = validation_batch_gen,
                   validation_steps = int(validation_data // batch_size),
                           )
# Out:
# Epoch 1/5
# 261/261 [==============================] - 447s 2s/step - loss: 1.4072 - accuracy: 0.5842 - val_loss: 0.7978 - val_accuracy: 0.4890
# Epoch 2/5
# 261/261 [==============================] - 440s 2s/step - loss: 0.6282 - accuracy: 0.6761 - val_loss: 0.6121 - val_accuracy: 0.6452
# Epoch 3/5
# 261/261 [==============================] - 440s 2s/step - loss: 0.5881 - accuracy: 0.7078 - val_loss: 0.5651 - val_accuracy: 0.7114
# Epoch 4/5
# 261/261 [==============================] - 431s 2s/step - loss: 0.5633 - accuracy: 0.7393 - val_loss: 0.6772 - val_accuracy: 0.6985
# Epoch 5/5
# 261/261 [==============================] - 432s 2s/step - loss: 0.5341 - accuracy: 0.7505 - val_loss: 0.6217 - val_accuracy: 0.7224

# %%
y_pred_mn=  model_mn.predict(validation_batch_gen)
y_pred = np.argmax(y_pred_mn,axis = 1)
y_act = np.argmax(val_y_data,axis = 1)

# %%
print(classification_report(y_act,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.60      0.69       278
#            1       0.69      0.85      0.76       285
#
#     accuracy                           0.73       563
#    macro avg       0.74      0.73      0.72       563
# weighted avg       0.74      0.73      0.72       563

# %%
metrics.cohen_kappa_score(y_act,y_pred)
# Out:
# 0.45478539916830707

# %%
confusion_matrix(y_act,y_pred)
# Out:
# array([[168, 110],
#        [ 43, 242]])

# %%
fpr, tpr, thresh = metrics.roc_curve(y_act,y_pred)
auc = metrics.roc_auc_score(y_act,y_pred)
plt.plot(fpr,tpr,label="MobileNet, auc="+str(auc))
plt.legend()

# %% [markdown]
# > # **ResNet50V2**

# %%
RNV2=keras.applications.ResNet50V2(include_top=False,input_shape=(224,224,3))
input_image=keras.layers.Input((224,224,3))
x=RNV2(input_image)

x=keras.layers.Flatten()(x)
x=keras.layers.Dense(256)(x)
x=keras.layers.Activation(activation='relu')(x)
x= keras.layers.Dropout(0.5)(x)
x=keras.layers.Dense(2)(x)
out=keras.layers.Activation(activation='softmax')(x)

model_rnv2=keras.Model(inputs=input_image,outputs=out)
model_rnv2.compile(optimizer=keras.optimizers.RMSprop(lr=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])
print(model_rnv2.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 7, 7, 2048)        23564800
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               25690368
# _________________________________________________________________
# activation_10 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 514
# _________________________________________________________________
# activation_11 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 49,255,682
# Trainable params: 49,210,242
# Non-trainable params: 45,440
# _________________________________________________________________
# None

# %%
history=model_rnv2.fit_generator(generator=training_batch_gen,
                   steps_per_epoch = int(training_data // batch_size),
                   epochs = 5,
                   verbose = 1,
                   class_weight=d_class_weights,
                   validation_data = validation_batch_gen,
                   validation_steps = int(validation_data // batch_size),
                           )
# Out:
# Epoch 1/5
# 261/261 [==============================] - 447s 2s/step - loss: 1.0422 - accuracy: 0.5902 - val_loss: 0.8281 - val_accuracy: 0.4890
# Epoch 2/5
# 261/261 [==============================] - 438s 2s/step - loss: 0.6351 - accuracy: 0.6726 - val_loss: 0.8533 - val_accuracy: 0.4871
# Epoch 3/5
# 261/261 [==============================] - 439s 2s/step - loss: 0.5943 - accuracy: 0.7308 - val_loss: 1.0966 - val_accuracy: 0.6360
# Epoch 4/5
# 261/261 [==============================] - 438s 2s/step - loss: 0.5791 - accuracy: 0.7344 - val_loss: 1.3413 - val_accuracy: 0.6710
# Epoch 5/5
# 261/261 [==============================] - 446s 2s/step - loss: 0.5392 - accuracy: 0.7516 - val_loss: 0.9747 - val_accuracy: 0.6029

# %%
y_pred_rnv2=  model_rnv2.predict(validation_batch_gen)
y_pred_rnv2 = np.argmax(y_pred_rnv2,axis = 1)
y_act = np.argmax(val_y_data,axis = 1)

# %%
print(classification_report(y_act,y_pred_rnv2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.70      0.64       278
#            1       0.64      0.52      0.57       285
#
#     accuracy                           0.61       563
#    macro avg       0.61      0.61      0.60       563
# weighted avg       0.61      0.61      0.60       563

# %%
metrics.cohen_kappa_score(y_act,y_pred_rnv2)
# Out:
# 0.21312280436671327

# %%
confusion_matrix(y_act,y_pred_rnv2)
# Out:
# array([[194,  84],
#        [138, 147]])

# %%
fpr, tpr, thresh = metrics.roc_curve(y_act,y_pred_rnv2)
auc = metrics.roc_auc_score(y_act,y_pred_rnv2)
plt.plot(fpr,tpr,label="ResNet50V2, auc="+str(auc))
plt.legend()

# %% [markdown]
# > # **Multi-Model**

# %% [markdown]
# **Here three different models are stacked together, Models used here are Xception,ResNet50V2 and MobileNet. All Layers of Xception are trained for the following training process and rest models layers are freezed.**

# %%
input_image=keras.layers.Input((224,224,3))

Xception = tf.keras.applications.Xception(input_tensor=input_image, weights='imagenet', include_top=False)       
for layer in Xception.layers:
    #layer.trainable = False
    layer._name = layer.name + str('_1')
    
MN = tf.keras.applications.MobileNet(input_tensor=input_image, weights='imagenet', include_top=False)       
for layer in MN.layers:
    layer.trainable = False
    layer._name = layer.name + str('_2')    
    

RNV2 = tf.keras.applications.ResNet50V2(input_tensor=input_image, weights='imagenet', include_top=False)       
for layer in RNV2.layers:
    layer.trainable = False
    layer._name = layer.name + str('_3')
    
concat_Output = tf.keras.layers.Concatenate()([Xception.output,MN.output,RNV2.output])

x=keras.layers.Flatten()(concat_Output)
x=keras.layers.Dense(256)(x)
x=keras.layers.Activation(activation='relu')(x)
x= keras.layers.Dropout(0.5)(x)
x=keras.layers.Dense(2)(x)
out=keras.layers.Activation(activation='softmax')(x)

model=keras.Model(inputs=input_image,outputs=out)
model.compile(optimizer=keras.optimizers.RMSprop(lr=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12_1_2_3 (InputLayer)     [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad_3 (ZeroPadding2D)     (None, 230, 230, 3)  0           input_12_1_2_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv_3 (Conv2D)           (None, 112, 112, 64) 9472        conv1_pad_3[0][0]
# __________________________________________________________________________________________________
# pool1_pad_3 (ZeroPadding2D)     (None, 114, 114, 64) 0           conv1_conv_3[0][0]
# __________________________________________________________________________________________________
# pool1_pool_3 (MaxPooling2D)     (None, 56, 56, 64)   0           pool1_pad_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn_3 (Batch (None, 56, 56, 64)   256         pool1_pool_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu_3 (Act (None, 56, 56, 64)   0           conv2_block1_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv_3 (Conv2D)  (None, 56, 56, 64)   4096        conv2_block1_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn_3 (BatchNorma (None, 56, 56, 64)   256         conv2_block1_1_conv_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu_3 (Activati (None, 56, 56, 64)   0           conv2_block1_1_bn_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad_3 (ZeroPaddi (None, 58, 58, 64)   0           conv2_block1_1_relu_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv_3 (Conv2D)  (None, 56, 56, 64)   36864       conv2_block1_2_pad_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn_3 (BatchNorma (None, 56, 56, 64)   256         conv2_block1_2_conv_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu_3 (Activati (None, 56, 56, 64)   0           conv2_block1_2_bn_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv_3 (Conv2D)  (None, 56, 56, 256)  16640       conv2_block1_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv_3 (Conv2D)  (None, 56, 56, 256)  16640       conv2_block1_2_relu_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out_3 (Add)        (None, 56, 56, 256)  0           conv2_block1_0_conv_3[0][0]
#                                                                  conv2_block1_3_conv_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn_3 (Batch (None, 56, 56, 256)  1024        conv2_block1_out_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu_3 (Act (None, 56, 56, 256)  0           conv2_block2_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv_3 (Conv2D)  (None, 56, 56, 64)   16384       conv2_block2_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn_3 (BatchNorma (None, 56, 56, 64)   256         conv2_block2_1_conv_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu_3 (Activati (None, 56, 56, 64)   0           conv2_block2_1_bn_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad_3 (ZeroPaddi (None, 58, 58, 64)   0           conv2_block2_1_relu_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv_3 (Conv2D)  (None, 56, 56, 64)   36864       conv2_block2_2_pad_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn_3 (BatchNorma (None, 56, 56, 64)   256         conv2_block2_2_conv_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu_3 (Activati (None, 56, 56, 64)   0           conv2_block2_2_bn_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv_3 (Conv2D)  (None, 56, 56, 256)  16640       conv2_block2_2_relu_3[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out_3 (Add)        (None, 56, 56, 256)  0           conv2_block1_out_3[0][0]
#                                                                  conv2_block2_3_conv_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn_3 (Batch (None, 56, 56, 256)  1024        conv2_block2_out_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu_3 (Act (None, 56, 56, 256)  0           conv2_block3_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv_3 (Conv2D)  (None, 56, 56, 64)   16384       conv2_block3_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn_3 (BatchNorma (None, 56, 56, 64)   256         conv2_block3_1_conv_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu_3 (Activati (None, 56, 56, 64)   0           conv2_block3_1_bn_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad_3 (ZeroPaddi (None, 58, 58, 64)   0           conv2_block3_1_relu_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv_3 (Conv2D)  (None, 28, 28, 64)   36864       conv2_block3_2_pad_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn_3 (BatchNorma (None, 28, 28, 64)   256         conv2_block3_2_conv_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu_3 (Activati (None, 28, 28, 64)   0           conv2_block3_2_bn_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3_3 (MaxPooling2D (None, 28, 28, 256)  0           conv2_block2_out_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv_3 (Conv2D)  (None, 28, 28, 256)  16640       conv2_block3_2_relu_3[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out_3 (Add)        (None, 28, 28, 256)  0           max_pooling2d_3_3[0][0]
#                                                                  conv2_block3_3_conv_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn_3 (Batch (None, 28, 28, 256)  1024        conv2_block3_out_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu_3 (Act (None, 28, 28, 256)  0           conv3_block1_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv_3 (Conv2D)  (None, 28, 28, 128)  32768       conv3_block1_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn_3 (BatchNorma (None, 28, 28, 128)  512         conv3_block1_1_conv_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu_3 (Activati (None, 28, 28, 128)  0           conv3_block1_1_bn_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad_3 (ZeroPaddi (None, 30, 30, 128)  0           conv3_block1_1_relu_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv_3 (Conv2D)  (None, 28, 28, 128)  147456      conv3_block1_2_pad_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn_3 (BatchNorma (None, 28, 28, 128)  512         conv3_block1_2_conv_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu_3 (Activati (None, 28, 28, 128)  0           conv3_block1_2_bn_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv_3 (Conv2D)  (None, 28, 28, 512)  131584      conv3_block1_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv_3 (Conv2D)  (None, 28, 28, 512)  66048       conv3_block1_2_relu_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out_3 (Add)        (None, 28, 28, 512)  0           conv3_block1_0_conv_3[0][0]
#                                                                  conv3_block1_3_conv_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn_3 (Batch (None, 28, 28, 512)  2048        conv3_block1_out_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu_3 (Act (None, 28, 28, 512)  0           conv3_block2_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv_3 (Conv2D)  (None, 28, 28, 128)  65536       conv3_block2_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn_3 (BatchNorma (None, 28, 28, 128)  512         conv3_block2_1_conv_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu_3 (Activati (None, 28, 28, 128)  0           conv3_block2_1_bn_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad_3 (ZeroPaddi (None, 30, 30, 128)  0           conv3_block2_1_relu_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv_3 (Conv2D)  (None, 28, 28, 128)  147456      conv3_block2_2_pad_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn_3 (BatchNorma (None, 28, 28, 128)  512         conv3_block2_2_conv_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu_3 (Activati (None, 28, 28, 128)  0           conv3_block2_2_bn_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv_3 (Conv2D)  (None, 28, 28, 512)  66048       conv3_block2_2_relu_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out_3 (Add)        (None, 28, 28, 512)  0           conv3_block1_out_3[0][0]
#                                                                  conv3_block2_3_conv_3[0][0]
# __________________________________________________________________________________________________
# block1_conv1_1 (Conv2D)         (None, 111, 111, 32) 864         input_12_1_2_3[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn_3 (Batch (None, 28, 28, 512)  2048        conv3_block2_out_3[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn_1 (BatchNormali (None, 111, 111, 32) 128         block1_conv1_1[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu_3 (Act (None, 28, 28, 512)  0           conv3_block3_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act_1 (Activation) (None, 111, 111, 32) 0           block1_conv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv_3 (Conv2D)  (None, 28, 28, 128)  65536       conv3_block3_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# block1_conv2_1 (Conv2D)         (None, 109, 109, 64) 18432       block1_conv1_act_1[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn_3 (BatchNorma (None, 28, 28, 128)  512         conv3_block3_1_conv_3[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn_1 (BatchNormali (None, 109, 109, 64) 256         block1_conv2_1[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu_3 (Activati (None, 28, 28, 128)  0           conv3_block3_1_bn_3[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act_1 (Activation) (None, 109, 109, 64) 0           block1_conv2_bn_1[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad_3 (ZeroPaddi (None, 30, 30, 128)  0           conv3_block3_1_relu_3[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_1 (SeparableCon (None, 109, 109, 128 8768        block1_conv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv_3 (Conv2D)  (None, 28, 28, 128)  147456      conv3_block3_2_pad_3[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn_1 (BatchNorm (None, 109, 109, 128 512         block2_sepconv1_1[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn_3 (BatchNorma (None, 28, 28, 128)  512         conv3_block3_2_conv_3[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act_1 (Activati (None, 109, 109, 128 0           block2_sepconv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu_3 (Activati (None, 28, 28, 128)  0           conv3_block3_2_bn_3[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_1 (SeparableCon (None, 109, 109, 128 17536       block2_sepconv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv_3 (Conv2D)  (None, 28, 28, 512)  66048       conv3_block3_2_relu_3[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn_1 (BatchNorm (None, 109, 109, 128 512         block2_sepconv2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 55, 55, 128)  8192        block1_conv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out_3 (Add)        (None, 28, 28, 512)  0           conv3_block2_out_3[0][0]
#                                                                  conv3_block3_3_conv_3[0][0]
# __________________________________________________________________________________________________
# block2_pool_1 (MaxPooling2D)    (None, 55, 55, 128)  0           block2_sepconv2_bn_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 55, 55, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn_3 (Batch (None, 28, 28, 512)  2048        conv3_block3_out_3[0][0]
# __________________________________________________________________________________________________
# add_16_1 (Add)                  (None, 55, 55, 128)  0           block2_pool_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu_3 (Act (None, 28, 28, 512)  0           conv3_block4_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act_1 (Activati (None, 55, 55, 128)  0           add_16_1[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv_3 (Conv2D)  (None, 28, 28, 128)  65536       conv3_block4_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_1 (SeparableCon (None, 55, 55, 256)  33920       block3_sepconv1_act_1[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn_3 (BatchNorma (None, 28, 28, 128)  512         conv3_block4_1_conv_3[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn_1 (BatchNorm (None, 55, 55, 256)  1024        block3_sepconv1_1[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu_3 (Activati (None, 28, 28, 128)  0           conv3_block4_1_bn_3[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act_1 (Activati (None, 55, 55, 256)  0           block3_sepconv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad_3 (ZeroPaddi (None, 30, 30, 128)  0           conv3_block4_1_relu_3[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_1 (SeparableCon (None, 55, 55, 256)  67840       block3_sepconv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv_3 (Conv2D)  (None, 14, 14, 128)  147456      conv3_block4_2_pad_3[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn_1 (BatchNorm (None, 55, 55, 256)  1024        block3_sepconv2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1_1 (Conv2D)             (None, 28, 28, 256)  32768       add_16_1[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn_3 (BatchNorma (None, 14, 14, 128)  512         conv3_block4_2_conv_3[0][0]
# __________________________________________________________________________________________________
# block3_pool_1 (MaxPooling2D)    (None, 28, 28, 256)  0           block3_sepconv2_bn_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1_1 (BatchN (None, 28, 28, 256)  1024        conv2d_1_1[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu_3 (Activati (None, 14, 14, 128)  0           conv3_block4_2_bn_3[0][0]
# __________________________________________________________________________________________________
# add_17_1 (Add)                  (None, 28, 28, 256)  0           block3_pool_1[0][0]
#                                                                  batch_normalization_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4_3 (MaxPooling2D (None, 14, 14, 512)  0           conv3_block3_out_3[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv_3 (Conv2D)  (None, 14, 14, 512)  66048       conv3_block4_2_relu_3[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act_1 (Activati (None, 28, 28, 256)  0           add_17_1[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out_3 (Add)        (None, 14, 14, 512)  0           max_pooling2d_4_3[0][0]
#                                                                  conv3_block4_3_conv_3[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_1 (SeparableCon (None, 28, 28, 728)  188672      block4_sepconv1_act_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn_3 (Batch (None, 14, 14, 512)  2048        conv3_block4_out_3[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn_1 (BatchNorm (None, 28, 28, 728)  2912        block4_sepconv1_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu_3 (Act (None, 14, 14, 512)  0           conv4_block1_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act_1 (Activati (None, 28, 28, 728)  0           block4_sepconv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv_3 (Conv2D)  (None, 14, 14, 256)  131072      conv4_block1_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_1 (SeparableCon (None, 28, 28, 728)  536536      block4_sepconv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn_3 (BatchNorma (None, 14, 14, 256)  1024        conv4_block1_1_conv_3[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn_1 (BatchNorm (None, 28, 28, 728)  2912        block4_sepconv2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2_1 (Conv2D)             (None, 14, 14, 728)  186368      add_17_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu_3 (Activati (None, 14, 14, 256)  0           conv4_block1_1_bn_3[0][0]
# __________________________________________________________________________________________________
# block4_pool_1 (MaxPooling2D)    (None, 14, 14, 728)  0           block4_sepconv2_bn_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2_1 (BatchN (None, 14, 14, 728)  2912        conv2d_2_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad_3 (ZeroPaddi (None, 16, 16, 256)  0           conv4_block1_1_relu_3[0][0]
# __________________________________________________________________________________________________
# add_18_1 (Add)                  (None, 14, 14, 728)  0           block4_pool_1[0][0]
#                                                                  batch_normalization_2_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv_3 (Conv2D)  (None, 14, 14, 256)  589824      conv4_block1_2_pad_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act_1 (Activati (None, 14, 14, 728)  0           add_18_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn_3 (BatchNorma (None, 14, 14, 256)  1024        conv4_block1_2_conv_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_1 (SeparableCon (None, 14, 14, 728)  536536      block5_sepconv1_act_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu_3 (Activati (None, 14, 14, 256)  0           conv4_block1_2_bn_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block5_sepconv1_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv_3 (Conv2D)  (None, 14, 14, 1024) 525312      conv4_block1_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv_3 (Conv2D)  (None, 14, 14, 1024) 263168      conv4_block1_2_relu_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act_1 (Activati (None, 14, 14, 728)  0           block5_sepconv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out_3 (Add)        (None, 14, 14, 1024) 0           conv4_block1_0_conv_3[0][0]
#                                                                  conv4_block1_3_conv_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_1 (SeparableCon (None, 14, 14, 728)  536536      block5_sepconv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn_3 (Batch (None, 14, 14, 1024) 4096        conv4_block1_out_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block5_sepconv2_1[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu_3 (Act (None, 14, 14, 1024) 0           conv4_block2_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act_1 (Activati (None, 14, 14, 728)  0           block5_sepconv2_bn_1[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv_3 (Conv2D)  (None, 14, 14, 256)  262144      conv4_block2_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_1 (SeparableCon (None, 14, 14, 728)  536536      block5_sepconv3_act_1[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn_3 (BatchNorma (None, 14, 14, 256)  1024        conv4_block2_1_conv_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block5_sepconv3_1[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu_3 (Activati (None, 14, 14, 256)  0           conv4_block2_1_bn_3[0][0]
# __________________________________________________________________________________________________
# add_19_1 (Add)                  (None, 14, 14, 728)  0           block5_sepconv3_bn_1[0][0]
#                                                                  add_18_1[0][0]
# __________________________________________________________________________________________________
# conv1_2 (Conv2D)                (None, 112, 112, 32) 864         input_12_1_2_3[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad_3 (ZeroPaddi (None, 16, 16, 256)  0           conv4_block2_1_relu_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act_1 (Activati (None, 14, 14, 728)  0           add_19_1[0][0]
# __________________________________________________________________________________________________
# conv1_bn_2 (BatchNormalization) (None, 112, 112, 32) 128         conv1_2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv_3 (Conv2D)  (None, 14, 14, 256)  589824      conv4_block2_2_pad_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_1 (SeparableCon (None, 14, 14, 728)  536536      block6_sepconv1_act_1[0][0]
# __________________________________________________________________________________________________
# conv1_relu_2 (ReLU)             (None, 112, 112, 32) 0           conv1_bn_2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn_3 (BatchNorma (None, 14, 14, 256)  1024        conv4_block2_2_conv_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block6_sepconv1_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_2 (DepthwiseConv2D)   (None, 112, 112, 32) 288         conv1_relu_2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu_3 (Activati (None, 14, 14, 256)  0           conv4_block2_2_bn_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act_1 (Activati (None, 14, 14, 728)  0           block6_sepconv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_bn_2 (BatchNormalizat (None, 112, 112, 32) 128         conv_dw_1_2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv_3 (Conv2D)  (None, 14, 14, 1024) 263168      conv4_block2_2_relu_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_1 (SeparableCon (None, 14, 14, 728)  536536      block6_sepconv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_relu_2 (ReLU)         (None, 112, 112, 32) 0           conv_dw_1_bn_2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out_3 (Add)        (None, 14, 14, 1024) 0           conv4_block1_out_3[0][0]
#                                                                  conv4_block2_3_conv_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block6_sepconv2_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_2 (Conv2D)            (None, 112, 112, 64) 2048        conv_dw_1_relu_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn_3 (Batch (None, 14, 14, 1024) 4096        conv4_block2_out_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act_1 (Activati (None, 14, 14, 728)  0           block6_sepconv2_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_bn_2 (BatchNormalizat (None, 112, 112, 64) 256         conv_pw_1_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu_3 (Act (None, 14, 14, 1024) 0           conv4_block3_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_1 (SeparableCon (None, 14, 14, 728)  536536      block6_sepconv3_act_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_relu_2 (ReLU)         (None, 112, 112, 64) 0           conv_pw_1_bn_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv_3 (Conv2D)  (None, 14, 14, 256)  262144      conv4_block3_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block6_sepconv3_1[0][0]
# __________________________________________________________________________________________________
# conv_pad_2_2 (ZeroPadding2D)    (None, 113, 113, 64) 0           conv_pw_1_relu_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn_3 (BatchNorma (None, 14, 14, 256)  1024        conv4_block3_1_conv_3[0][0]
# __________________________________________________________________________________________________
# add_20_1 (Add)                  (None, 14, 14, 728)  0           block6_sepconv3_bn_1[0][0]
#                                                                  add_19_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_2 (DepthwiseConv2D)   (None, 56, 56, 64)   576         conv_pad_2_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu_3 (Activati (None, 14, 14, 256)  0           conv4_block3_1_bn_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act_1 (Activati (None, 14, 14, 728)  0           add_20_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_bn_2 (BatchNormalizat (None, 56, 56, 64)   256         conv_dw_2_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad_3 (ZeroPaddi (None, 16, 16, 256)  0           conv4_block3_1_relu_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_1 (SeparableCon (None, 14, 14, 728)  536536      block7_sepconv1_act_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_relu_2 (ReLU)         (None, 56, 56, 64)   0           conv_dw_2_bn_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv_3 (Conv2D)  (None, 14, 14, 256)  589824      conv4_block3_2_pad_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block7_sepconv1_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_2 (Conv2D)            (None, 56, 56, 128)  8192        conv_dw_2_relu_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn_3 (BatchNorma (None, 14, 14, 256)  1024        conv4_block3_2_conv_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act_1 (Activati (None, 14, 14, 728)  0           block7_sepconv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_bn_2 (BatchNormalizat (None, 56, 56, 128)  512         conv_pw_2_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu_3 (Activati (None, 14, 14, 256)  0           conv4_block3_2_bn_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_1 (SeparableCon (None, 14, 14, 728)  536536      block7_sepconv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_relu_2 (ReLU)         (None, 56, 56, 128)  0           conv_pw_2_bn_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv_3 (Conv2D)  (None, 14, 14, 1024) 263168      conv4_block3_2_relu_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block7_sepconv2_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_2 (DepthwiseConv2D)   (None, 56, 56, 128)  1152        conv_pw_2_relu_2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out_3 (Add)        (None, 14, 14, 1024) 0           conv4_block2_out_3[0][0]
#                                                                  conv4_block3_3_conv_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act_1 (Activati (None, 14, 14, 728)  0           block7_sepconv2_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_bn_2 (BatchNormalizat (None, 56, 56, 128)  512         conv_dw_3_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn_3 (Batch (None, 14, 14, 1024) 4096        conv4_block3_out_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_1 (SeparableCon (None, 14, 14, 728)  536536      block7_sepconv3_act_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_relu_2 (ReLU)         (None, 56, 56, 128)  0           conv_dw_3_bn_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu_3 (Act (None, 14, 14, 1024) 0           conv4_block4_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block7_sepconv3_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_2 (Conv2D)            (None, 56, 56, 128)  16384       conv_dw_3_relu_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv_3 (Conv2D)  (None, 14, 14, 256)  262144      conv4_block4_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# add_21_1 (Add)                  (None, 14, 14, 728)  0           block7_sepconv3_bn_1[0][0]
#                                                                  add_20_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_bn_2 (BatchNormalizat (None, 56, 56, 128)  512         conv_pw_3_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn_3 (BatchNorma (None, 14, 14, 256)  1024        conv4_block4_1_conv_3[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act_1 (Activati (None, 14, 14, 728)  0           add_21_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_relu_2 (ReLU)         (None, 56, 56, 128)  0           conv_pw_3_bn_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu_3 (Activati (None, 14, 14, 256)  0           conv4_block4_1_bn_3[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_1 (SeparableCon (None, 14, 14, 728)  536536      block8_sepconv1_act_1[0][0]
# __________________________________________________________________________________________________
# conv_pad_4_2 (ZeroPadding2D)    (None, 57, 57, 128)  0           conv_pw_3_relu_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad_3 (ZeroPaddi (None, 16, 16, 256)  0           conv4_block4_1_relu_3[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block8_sepconv1_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_2 (DepthwiseConv2D)   (None, 28, 28, 128)  1152        conv_pad_4_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv_3 (Conv2D)  (None, 14, 14, 256)  589824      conv4_block4_2_pad_3[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act_1 (Activati (None, 14, 14, 728)  0           block8_sepconv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_bn_2 (BatchNormalizat (None, 28, 28, 128)  512         conv_dw_4_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn_3 (BatchNorma (None, 14, 14, 256)  1024        conv4_block4_2_conv_3[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_1 (SeparableCon (None, 14, 14, 728)  536536      block8_sepconv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_relu_2 (ReLU)         (None, 28, 28, 128)  0           conv_dw_4_bn_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu_3 (Activati (None, 14, 14, 256)  0           conv4_block4_2_bn_3[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn_1 (BatchNorm (None, 14, 14, 728)  2912        block8_sepconv2_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_2 (Conv2D)            (None, 28, 28, 256)  32768       conv_dw_4_relu_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv_3 (Conv2D)  (None, 14, 14, 1024) 263168      conv4_block4_2_relu_3[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act_1 (Activati (None, 14, 14, 728)  0           block8_sepconv2_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_bn_2 (BatchNormalizat (None, 28, 28, 256)  1024        conv_pw_4_2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out_3 (Add)        (None, 14, 14, 1024) 0           conv4_block3_out_3[0][0]
#                                                                  conv4_block4_3_conv_3[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv5_block2_preact_relu_3 (Act (None, 7, 7, 2048)   0           conv5_block2_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn_1 (BatchNor (None, 14, 14, 728)  2912        block12_sepconv1_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_2 (Conv2D)           (None, 14, 14, 512)  262144      conv_dw_10_relu_2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv_3 (Conv2D)  (None, 7, 7, 512)    1048576     conv5_block2_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act_1 (Activat (None, 14, 14, 728)  0           block12_sepconv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_bn_2 (BatchNormaliza (None, 14, 14, 512)  2048        conv_pw_10_2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn_3 (BatchNorma (None, 7, 7, 512)    2048        conv5_block2_1_conv_3[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_1 (SeparableCo (None, 14, 14, 728)  536536      block12_sepconv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_relu_2 (ReLU)        (None, 14, 14, 512)  0           conv_pw_10_bn_2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu_3 (Activati (None, 7, 7, 512)    0           conv5_block2_1_bn_3[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn_1 (BatchNor (None, 14, 14, 728)  2912        block12_sepconv2_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_2 (DepthwiseConv2D)  (None, 14, 14, 512)  4608        conv_pw_10_relu_2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad_3 (ZeroPaddi (None, 9, 9, 512)    0           conv5_block2_1_relu_3[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act_1 (Activat (None, 14, 14, 728)  0           block12_sepconv2_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_bn_2 (BatchNormaliza (None, 14, 14, 512)  2048        conv_dw_11_2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv_3 (Conv2D)  (None, 7, 7, 512)    2359296     conv5_block2_2_pad_3[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_1 (SeparableCo (None, 14, 14, 728)  536536      block12_sepconv3_act_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_relu_2 (ReLU)        (None, 14, 14, 512)  0           conv_dw_11_bn_2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn_3 (BatchNorma (None, 7, 7, 512)    2048        conv5_block2_2_conv_3[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn_1 (BatchNor (None, 14, 14, 728)  2912        block12_sepconv3_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_2 (Conv2D)           (None, 14, 14, 512)  262144      conv_dw_11_relu_2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu_3 (Activati (None, 7, 7, 512)    0           conv5_block2_2_bn_3[0][0]
# __________________________________________________________________________________________________
# add_26_1 (Add)                  (None, 14, 14, 728)  0           block12_sepconv3_bn_1[0][0]
#                                                                  add_25_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_bn_2 (BatchNormaliza (None, 14, 14, 512)  2048        conv_pw_11_2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv_3 (Conv2D)  (None, 7, 7, 2048)   1050624     conv5_block2_2_relu_3[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act_1 (Activat (None, 14, 14, 728)  0           add_26_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_relu_2 (ReLU)        (None, 14, 14, 512)  0           conv_pw_11_bn_2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out_3 (Add)        (None, 7, 7, 2048)   0           conv5_block1_out_3[0][0]
#                                                                  conv5_block2_3_conv_3[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_1 (SeparableCo (None, 14, 14, 728)  536536      block13_sepconv1_act_1[0][0]
# __________________________________________________________________________________________________
# conv_pad_12_2 (ZeroPadding2D)   (None, 15, 15, 512)  0           conv_pw_11_relu_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn_3 (Batch (None, 7, 7, 2048)   8192        conv5_block2_out_3[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn_1 (BatchNor (None, 14, 14, 728)  2912        block13_sepconv1_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_2 (DepthwiseConv2D)  (None, 7, 7, 512)    4608        conv_pad_12_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu_3 (Act (None, 7, 7, 2048)   0           conv5_block3_preact_bn_3[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act_1 (Activat (None, 14, 14, 728)  0           block13_sepconv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_bn_2 (BatchNormaliza (None, 7, 7, 512)    2048        conv_dw_12_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv_3 (Conv2D)  (None, 7, 7, 512)    1048576     conv5_block3_preact_relu_3[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_1 (SeparableCo (None, 14, 14, 1024) 752024      block13_sepconv2_act_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_relu_2 (ReLU)        (None, 7, 7, 512)    0           conv_dw_12_bn_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn_3 (BatchNorma (None, 7, 7, 512)    2048        conv5_block3_1_conv_3[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn_1 (BatchNor (None, 14, 14, 1024) 4096        block13_sepconv2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3_1 (Conv2D)             (None, 7, 7, 1024)   745472      add_26_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_2 (Conv2D)           (None, 7, 7, 1024)   524288      conv_dw_12_relu_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu_3 (Activati (None, 7, 7, 512)    0           conv5_block3_1_bn_3[0][0]
# __________________________________________________________________________________________________
# block13_pool_1 (MaxPooling2D)   (None, 7, 7, 1024)   0           block13_sepconv2_bn_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3_1 (BatchN (None, 7, 7, 1024)   4096        conv2d_3_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_bn_2 (BatchNormaliza (None, 7, 7, 1024)   4096        conv_pw_12_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad_3 (ZeroPaddi (None, 9, 9, 512)    0           conv5_block3_1_relu_3[0][0]
# __________________________________________________________________________________________________
# add_27_1 (Add)                  (None, 7, 7, 1024)   0           block13_pool_1[0][0]
#                                                                  batch_normalization_3_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_relu_2 (ReLU)        (None, 7, 7, 1024)   0           conv_pw_12_bn_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv_3 (Conv2D)  (None, 7, 7, 512)    2359296     conv5_block3_2_pad_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_1 (SeparableCo (None, 7, 7, 1536)   1582080     add_27_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_2 (DepthwiseConv2D)  (None, 7, 7, 1024)   9216        conv_pw_12_relu_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn_3 (BatchNorma (None, 7, 7, 512)    2048        conv5_block3_2_conv_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn_1 (BatchNor (None, 7, 7, 1536)   6144        block14_sepconv1_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_bn_2 (BatchNormaliza (None, 7, 7, 1024)   4096        conv_dw_13_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu_3 (Activati (None, 7, 7, 512)    0           conv5_block3_2_bn_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act_1 (Activat (None, 7, 7, 1536)   0           block14_sepconv1_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_relu_2 (ReLU)        (None, 7, 7, 1024)   0           conv_dw_13_bn_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv_3 (Conv2D)  (None, 7, 7, 2048)   1050624     conv5_block3_2_relu_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_1 (SeparableCo (None, 7, 7, 2048)   3159552     block14_sepconv1_act_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_2 (Conv2D)           (None, 7, 7, 1024)   1048576     conv_dw_13_relu_2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out_3 (Add)        (None, 7, 7, 2048)   0           conv5_block2_out_3[0][0]
#                                                                  conv5_block3_3_conv_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn_1 (BatchNor (None, 7, 7, 2048)   8192        block14_sepconv2_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_bn_2 (BatchNormaliza (None, 7, 7, 1024)   4096        conv_pw_13_2[0][0]
# __________________________________________________________________________________________________
# post_bn_3 (BatchNormalization)  (None, 7, 7, 2048)   8192        conv5_block3_out_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act_1 (Activat (None, 7, 7, 2048)   0           block14_sepconv2_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_relu_2 (ReLU)        (None, 7, 7, 1024)   0           conv_pw_13_bn_2[0][0]
# __________________________________________________________________________________________________
# post_relu_3 (Activation)        (None, 7, 7, 2048)   0           post_bn_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 5120)   0           block14_sepconv2_act_1[0][0]
#                                                                  conv_pw_13_relu_2[0][0]
#                                                                  post_relu_3[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 250880)       0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 256)          64225536    flatten_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 256)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256)          0           activation_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 2)            514         dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 2)            0           dense_13[0][0]
# ==================================================================================================
# Total params: 111,881,194
# Trainable params: 85,033,002
# Non-trainable params: 26,848,192
# __________________________________________________________________________________________________
# None

# %% [markdown]
# > # **Train the Model**

# %%
history=model.fit_generator(generator=training_batch_gen,
                   steps_per_epoch = int(training_data // batch_size),
                   epochs = 5,
                   verbose = 1,
                   class_weight=d_class_weights,
                   validation_data = validation_batch_gen,
                   validation_steps = int(validation_data // batch_size),
                           )
# Out:
# Epoch 1/5
# 261/261 [==============================] - 456s 2s/step - loss: 0.4256 - accuracy: 0.8236 - val_loss: 1.7273 - val_accuracy: 0.7812
# Epoch 2/5
# 261/261 [==============================] - 456s 2s/step - loss: 0.3909 - accuracy: 0.8293 - val_loss: 2.5505 - val_accuracy: 0.7978
# Epoch 3/5
# 261/261 [==============================] - 457s 2s/step - loss: 0.3714 - accuracy: 0.8441 - val_loss: 3.5052 - val_accuracy: 0.7721
# Epoch 4/5
# 261/261 [==============================] - 451s 2s/step - loss: 0.3507 - accuracy: 0.8603 - val_loss: 2.9703 - val_accuracy: 0.7960
# Epoch 5/5
# 261/261 [==============================] - 458s 2s/step - loss: 0.3395 - accuracy: 0.8625 - val_loss: 3.0689 - val_accuracy: 0.7739

# %% [markdown]
# > # **Evaluation**

# %%
y_pred=  model.predict(validation_batch_gen)
y_pred = np.argmax(y_pred,axis = 1)
y_act = np.argmax(val_y_data,axis = 1)

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_act,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.64      0.74       278
#            1       0.72      0.92      0.81       285
#
#     accuracy                           0.78       563
#    macro avg       0.80      0.78      0.78       563
# weighted avg       0.80      0.78      0.78       563

# %% [markdown]
# **Cohen Kappa**

# %%
metrics.cohen_kappa_score(y_act,y_pred)
# Out:
# 0.5614959378423389

# %% [markdown]
# **Confusion Matrix**

# %%
confusion_matrix(y_act,y_pred)
# Out:
# array([[178, 100],
#        [ 23, 262]])

# %% [markdown]
# **Roc-Auc Curve**

# %%
fpr, tpr, thresh = metrics.roc_curve(y_act,y_pred)
auc = metrics.roc_auc_score(y_act,y_pred)
plt.plot(fpr,tpr,label="Multi-Model, auc="+str(auc))
plt.legend()

# %%
plt.xticks?
